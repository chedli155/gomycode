# %%
import pandas as pd

# %%
data=pd.read_csv(filepath_or_buffer=r'C:\Users\21699\Downloads\kc_house_data.csv')
data.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 17 , 15 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plot_correlation_map(data)

# %%
data1=data[["price","bedrooms","bathrooms","sqft_living","sqft_lot","floors","grade","zipcode", "sqft_living15", "waterfront", "view", "sqft_basement"]]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X=data1["sqft_living"].values[:,np.newaxis]
print(X)
y=data1["price"]
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=30)
# Out:
# [[1180]
#  [2570]
#  [ 770]
#  ...
#  [1020]
#  [1600]
#  [1020]]

# %%
from sklearn.linear_model import LinearRegression

LR_model = LinearRegression()
LR_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test, color='blue')
plt.title("Linear Regression")
plt.xlabel("Confirmed")
plt.ylabel("Deaths")
plt.plot(x_test,model.predict(x_test),color="black")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a6f2afaf01b5> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(x_test,y_test, color='blue')
#       3 plt.title("Linear Regression")
#       4 plt.xlabel("Confirmed")
#       5 plt.ylabel("Deaths")
#
# NameError: name 'x_test' is not defined

# %%
from sklearn import metrics
LR_predicted = LR_model.predict(X_test)
print(LR_predicted)
print("LR MSE = ",metrics.mean_squared_error(y_test, LR_predicted))
print("LR R squared = ",metrics.r2_score(y_test, LR_predicted))
# Out:
# [532392.35758624 625630.42454452 625630.42454452 ... 862963.68589286
#  868614.47782972 549344.73339684]
# LR MSE =  64179676631.68388
# LR R squared =  0.4879814110728805

# %%
data2 = data1[data1['sqft_living'] <10000]
X=data2["sqft_living"].values[:,np.newaxis]
y=data2["price"]
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=30)
LR_model.fit(X_train, y_train)
LR_predicted = LR_model.predict(X_test)
print(LR_predicted)
print("LR MSE = ",metrics.mean_squared_error(y_test, LR_predicted))
print("LR R squared = ",metrics.r2_score(y_test, LR_predicted))
# Out:
# [ 531995.63610555  623342.62936787  343765.46817109 ... 1451001.75013853
#   855862.24858103  562444.63385966]
# LR MSE =  65576517827.32595
# LR R squared =  0.5014107582198329

# %%
X=data[["bedrooms","bathrooms","sqft_living","sqft_lot","floors","grade","zipcode"]]
y=data["price"].values
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=30)
MLR_model = LinearRegression()
MLR_model.fit(X_train,y_train)
MLR_predicted = MLR_model.predict(X_test)
print("MLR MSE = ",metrics.mean_squared_error(y_test, MLR_predicted))
print("MLR R squared = ",metrics.r2_score(y_test, MLR_predicted))
# Out:
# MLR MSE =  55011789284.373116
# MLR R squared =  0.5611218347922403

# %%
X=data[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','grade','sqft_above','sqft_basement','lat','long','sqft_living15']]
y=data["price"].values
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=30)
MLR_model = LinearRegression()
MLR_model.fit(X_train,y_train)
MLR_predicted = MLR_model.predict(X_test)
print("MLR MSE = ",metrics.mean_squared_error(y_test, MLR_predicted))
print("MLR R squared = ",metrics.r2_score(y_test, MLR_predicted))
# Out:
# MLR MSE =  38734585376.445755
# MLR R squared =  0.6909796248905713

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
New_X_train = poly.fit_transform(X_train)
New_X_test= poly.fit_transform(X_test)
PR_model = LinearRegression()
PR_model.fit(New_X_train,y_train)
PR_predicted = PR_model.predict(New_X_test)
print("MLR MSE = ",metrics.mean_squared_error(y_test, PR_predicted))
print("MLR R squared = ",metrics.r2_score(y_test, PR_predicted))
# Out:
# MLR MSE =  26571429437.04789
# MLR R squared =  0.7880159807564797
